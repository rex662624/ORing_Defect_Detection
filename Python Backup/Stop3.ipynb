# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import sklearn
from scipy import ndimage, misc
import math
# %matplotlib inline
import cv2
import time
import glob
from scipy.ndimage import gaussian_filter1d
from scipy import signal

img_list = []
filenamelist= []
for img in glob.glob("0525_images/CCD-3/*.jpg"):
    #img_list.append(cv2.imread(img,0))
    filenamelist.append(img)
np.array(filenamelist).shape
# Out:
# (152,)

# %%
threshold_1phase = 100
threshold_2phase_1 = 35#30
threshold_2phase_2 = 10#20
blur_size = 3
neighbor_degree = 5


for iter_file in range(len(filenamelist)):
    
    #==============read in file==============================
    start = time.time()
    filename = filenamelist[iter_file]
    print(filename)
    image = np.array(cv2.imread(filename,0))
    
    backtorgb = cv2.cvtColor(image,cv2.COLOR_GRAY2RGB)
    
    #==============use canny to find the contour
#     image_blur = cv2.blur(image,(9,9))
#     canny = cv2.Canny(image_blur,5,20)
    ret, thresh1 = cv2.threshold(image, 70, 255, cv2.THRESH_BINARY_INV)
    open_kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(4,3))
    thresh1 = cv2.morphologyEx(thresh1, cv2.MORPH_OPEN, open_kernel)
    print(thresh1.shape)
    # ===========cut the ROI by the canny edge image================
    _ , contours, hierarchy = cv2.findContours(thresh1,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    approx_list = []
    index = []
    for i in range(np.array(contours).shape[0]):
        if (hierarchy[0][i][3] >= 0):
            if(cv2.contourArea(contours[i])>300000 and cv2.contourArea(contours[i])<500000):
                epsilon = 0.005# * cv2.arcLength(contours[i],True)
                index.append(i)
                approx = cv2.approxPolyDP(contours[i], epsilon, True)
                approx_list.append(approx)
    #==========================================find outer circle==============================================
    ret, thresh1 = cv2.threshold(image, 110, 255, cv2.THRESH_BINARY_INV)

    c,r = cv2.minEnclosingCircle(approx_list[0])
    r = int(r)
    cx = int(c[0])
    cy = int(c[1])
    # ===========mask the image to extract the inner circle================
    inner_contour_img = np.zeros_like(image)
    cv2.circle(inner_contour_img,(cx,cy),(r+7), (255,255,255),-1)
    #inner_contour_img = 1 - inner_contour_img
    oringmask = inner_contour_img
    image[oringmask == 0] = 255
    #=======optinal blur
    image = cv2.blur(image,(blur_size, blur_size))
    #============create 0.5 degree a line

    const = np.pi/180
    x = []
    y = []
    inner_x = []
    inner_y = []

    degree_delta = 0.5
    for degree in range(int(360//degree_delta)):

        degree_real = degree_delta*degree
        now_x = int((r+2)*np.sin(degree_real*const))+cx
        now_y = int((r+2)*np.cos(degree_real*const))+cy
        now_inner_x = int((r-30)*np.sin(degree_real*const))+cx
        now_inner_y = int((r-30)*np.cos(degree_real*const))+cy

        x.append(now_x)
        y.append(now_y)
        inner_x.append(now_inner_x)
        inner_y.append(now_inner_y)
        
        #============shot from center
        
    threshold_1phase = 100
    threshold_2phase = 10
    all_diff_list = []
    all_min_list = []
    degree_1phase_list = []
    for degree in range(int(360//degree_delta)):
        points_on_line = np.linspace((inner_x[degree], inner_y[degree]),(x[degree],y[degree]) ,200,dtype = int)
        pass_list = image[points_on_line[:,1],points_on_line[:,0]]
        
        #First use gaussian filter to make the curve smooth,and then find peaks and valley.
        pass_list = gaussian_filter1d(pass_list,4)
        peaks, _ = signal.find_peaks(pass_list, height=0, prominence = 10)
        valley, _ = signal.find_peaks(-pass_list, height=0, prominence = 10)
        peak_and_valley_list = np.concatenate((pass_list[peaks], pass_list[valley]), axis=0)
        
        #cacluate the difference of every peak-valley
        shift_peak_and_valley_list = np.concatenate((np.array([0]), peak_and_valley_list))
        peak_and_valley_list = np.concatenate((peak_and_valley_list,np.array([0])))
        diff_list = abs(peak_and_valley_list - shift_peak_and_valley_list)    
        diff_list = diff_list[1::2]
        
        if(len(peaks)==0 or len(valley)==0 ):#如果沒找到local min 和max
            all_diff_list.append(-1)
            all_min_list.append(-1)
            #cv2.line(backtorgb,(inner_x[degree],inner_y[degree]),(x[degree],y[degree]),255,2)
            #cv2.circle(backtorgb,(x[degree],y[degree]),30, (0,255 ,255), 5)
            continue
            
        now_diff = max(diff_list)
        all_diff_list.append(now_diff)
        all_min_list.append(min(pass_list[valley]))
        
        #如果valley pixel>120 或差值<某個值
        if((min(pass_list[valley])>120 or now_diff<threshold_1phase)): 
            degree_1phase_list.append(degree)
            
    #第一階段有問題的degree，第二階段看看是不是真的有問題        
    for i in range(len(degree_1phase_list)):
        degree = degree_1phase_list[i]
        now_valley_value = all_min_list[degree]
        prev_valley_value = all_min_list[(degree+neighbor_degree)%720]
        next_valley_value = all_min_list[(degree-neighbor_degree)%720]

        now_peak_valley_difference = all_diff_list[degree]
        prev_peak_valley_difference = all_diff_list[(degree+neighbor_degree)%int(360//degree_delta)]
        next_peak_valley_difference = all_diff_list[(degree-neighbor_degree)%int(360//degree_delta)]
        
        if(((float(now_valley_value)-float(prev_valley_value)) + (float(now_valley_value) - float(next_valley_value))>threshold_2phase_1)
           and ((float(prev_peak_valley_difference)-float(now_peak_valley_difference))+(float(next_peak_valley_difference)-float(now_peak_valley_difference)))>threshold_2phase_2):
            #cv2.line(backtorgb,(inner_x[degree],inner_y[degree]),(x[degree],y[degree]),255,2)
            cv2.circle(backtorgb,(x[degree],y[degree]),30, (0,255 ,255), 5)
    
    end = time.time()
    print(end - start)
    print(".\\Detect\\Stop3\\" +filenamelist[iter_file][18:-4]+'_Detect.jpg')
    cv2.imwrite(".\\Detect\\Stop3\\" +filenamelist[iter_file][18:-4]+'_Detect.jpg',backtorgb)
# Out:
# 0525_images/CCD-3\1.jpg
# (2048, 2448)
# 0.3032081127166748
# .\Detect\Stop3\1_Detect.jpg
# 0525_images/CCD-3\10.jpg
# (2048, 2448)
# 0.2902212142944336
# .\Detect\Stop3\10_Detect.jpg
# 0525_images/CCD-3\100.jpg
# (2048, 2448)
# 0.2852184772491455
# .\Detect\Stop3\100_Detect.jpg
# 0525_images/CCD-3\101.jpg
# (2048, 2448)
# 0.31017327308654785
# .\Detect\Stop3\101_Detect.jpg
# 0525_images/CCD-3\102.jpg
# (2048, 2448)
# 0.2972385883331299
# .\Detect\Stop3\102_Detect.jpg
# 0525_images/CCD-3\103.jpg
# (2048, 2448)
# 0.30817508697509766
# .\Detect\Stop3\103_Detect.jpg
# 0525_images/CCD-3\104.jpg
# (2048, 2448)
# 0.3091728687286377
# .\Detect\Stop3\104_Detect.jpg
# 0525_images/CCD-3\105.jpg
# (2048, 2448)
# 0.29128289222717285
# .\Detect\Stop3\105_Detect.jpg
# 0525_images/CCD-3\106.jpg
# (2048, 2448)
# 0.29121828079223633
# .\Detect\Stop3\106_Detect.jpg
# 0525_images/CCD-3\107.jpg
# (2048, 2448)
# 0.28722620010375977
# .\Detect\Stop3\107_Detect.jpg
# 0525_images/CCD-3\108.jpg
# (2048, 2448)
# 0.28324270248413086
# .\Detect\Stop3\108_Detect.jpg
# 0525_images/CCD-3\109.jpg
# (2048, 2448)
# 0.2892129421234131
# .\Detect\Stop3\109_Detect.jpg
# 0525_images/CCD-3\11.jpg
# (2048, 2448)
# 0.2991981506347656
# .\Detect\Stop3\11_Detect.jpg
# 0525_images/CCD-3\110.jpg
# (2048, 2448)
# 0.27825498580932617
# .\Detect\Stop3\110_Detect.jpg
# 0525_images/CCD-3\111.jpg
# (2048, 2448)
# 0.40887999534606934
# .\Detect\Stop3\111_Detect.jpg
# 0525_images/CCD-3\112.jpg
# (2048, 2448)
# 0.3670470714569092
# .\Detect\Stop3\112_Detect.jpg
# 0525_images/CCD-3\113.jpg
# (2048, 2448)
# 0.29421281814575195
# .\Detect\Stop3\113_Detect.jpg
# 0525_images/CCD-3\114.jpg
# (2048, 2448)
# 0.3171529769897461
# .\Detect\Stop3\114_Detect.jpg
# 0525_images/CCD-3\115.jpg
# (2048, 2448)
# 0.30518054962158203
# .\Detect\Stop3\115_Detect.jpg
# 0525_images/CCD-3\116.jpg
# (2048, 2448)
# 0.3121368885040283
# .\Detect\Stop3\116_Detect.jpg
# 0525_images/CCD-3\117.jpg
# (2048, 2448)
# 0.3181486129760742
# .\Detect\Stop3\117_Detect.jpg
# 0525_images/CCD-3\118.jpg
# (2048, 2448)
# 0.30017948150634766
# .\Detect\Stop3\118_Detect.jpg
# 0525_images/CCD-3\119.jpg
# (2048, 2448)
# 0.31316256523132324
# .\Detect\Stop3\119_Detect.jpg
# 0525_images/CCD-3\12.jpg
# (2048, 2448)
# 0.3001999855041504
# .\Detect\Stop3\12_Detect.jpg
# 0525_images/CCD-3\120.jpg
# (2048, 2448)
# 0.28820109367370605
# .\Detect\Stop3\120_Detect.jpg
# 0525_images/CCD-3\121.jpg
# (2048, 2448)
# 0.2872600555419922
# .\Detect\Stop3\121_Detect.jpg
# 0525_images/CCD-3\122.jpg
# (2048, 2448)
# 0.2932441234588623
# .\Detect\Stop3\122_Detect.jpg
# 0525_images/CCD-3\123.jpg
# (2048, 2448)
# 0.2872288227081299
# .\Detect\Stop3\123_Detect.jpg
# 0525_images/CCD-3\124.jpg
# (2048, 2448)
# 0.32410669326782227
# .\Detect\Stop3\124_Detect.jpg
# 0525_images/CCD-3\125.jpg
# (2048, 2448)
# 0.36300039291381836
# .\Detect\Stop3\125_Detect.jpg
# 0525_images/CCD-3\126.jpg
# (2048, 2448)
# 0.31116724014282227
# .\Detect\Stop3\126_Detect.jpg
# 0525_images/CCD-3\127.jpg
# (2048, 2448)
# 0.3590402603149414
# .\Detect\Stop3\127_Detect.jpg
# 0525_images/CCD-3\128.jpg
# (2048, 2448)
# 0.2942390441894531
# .\Detect\Stop3\128_Detect.jpg
# 0525_images/CCD-3\129.jpg
# (2048, 2448)
# 0.3071780204772949
# .\Detect\Stop3\129_Detect.jpg
# 0525_images/CCD-3\13.jpg
# (2048, 2448)
# 0.2912180423736572
# .\Detect\Stop3\13_Detect.jpg
# 0525_images/CCD-3\130.jpg
# (2048, 2448)
# 0.3091444969177246
# .\Detect\Stop3\130_Detect.jpg
# 0525_images/CCD-3\131.jpg
# (2048, 2448)
# 0.2902412414550781
# .\Detect\Stop3\131_Detect.jpg
# 0525_images/CCD-3\132.jpg
# (2048, 2448)
# 0.2842392921447754
# .\Detect\Stop3\132_Detect.jpg
# 0525_images/CCD-3\133.jpg
# (2048, 2448)
# 0.2961747646331787
# .\Detect\Stop3\133_Detect.jpg
# 0525_images/CCD-3\134.jpg
# (2048, 2448)
# 0.28822994232177734
# .\Detect\Stop3\134_Detect.jpg
# 0525_images/CCD-3\135.jpg
# (2048, 2448)
# 0.2852637767791748
# .\Detect\Stop3\135_Detect.jpg
# 0525_images/CCD-3\136.jpg
# (2048, 2448)
# 0.291243314743042
# .\Detect\Stop3\136_Detect.jpg
# 0525_images/CCD-3\137.jpg
# (2048, 2448)
# 0.2932100296020508
# .\Detect\Stop3\137_Detect.jpg
# 0525_images/CCD-3\138.jpg
# (2048, 2448)
# 0.3111400604248047
# .\Detect\Stop3\138_Detect.jpg
# 0525_images/CCD-3\139.jpg
# (2048, 2448)
# 0.29521703720092773
# .\Detect\Stop3\139_Detect.jpg
# 0525_images/CCD-3\14.jpg
# (2048, 2448)
# 0.3310863971710205
# .\Detect\Stop3\14_Detect.jpg
# 0525_images/CCD-3\140.jpg
# (2048, 2448)
# 0.42984938621520996
# .\Detect\Stop3\140_Detect.jpg
# 0525_images/CCD-3\141.jpg
# (2048, 2448)
# 0.3470571041107178
# .\Detect\Stop3\141_Detect.jpg
# 0525_images/CCD-3\142.jpg
# (2048, 2448)
# 0.3011956214904785
# .\Detect\Stop3\142_Detect.jpg
# 0525_images/CCD-3\143.jpg
# (2048, 2448)
# 0.32012009620666504
# .\Detect\Stop3\143_Detect.jpg
# 0525_images/CCD-3\144.jpg
# (2048, 2448)
# 0.30521297454833984
# .\Detect\Stop3\144_Detect.jpg
# 0525_images/CCD-3\145.jpg
# (2048, 2448)
# 0.3001976013183594
# .\Detect\Stop3\145_Detect.jpg
# 0525_images/CCD-3\146.jpg
# (2048, 2448)
# 0.31516575813293457
# .\Detect\Stop3\146_Detect.jpg
# 0525_images/CCD-3\147.jpg
# (2048, 2448)
# 0.3042168617248535
# .\Detect\Stop3\147_Detect.jpg
# 0525_images/CCD-3\148.jpg
# (2048, 2448)
# 0.3161811828613281
# .\Detect\Stop3\148_Detect.jpg
# 0525_images/CCD-3\149.jpg
# (2048, 2448)
# 0.29620838165283203
# .\Detect\Stop3\149_Detect.jpg
# 0525_images/CCD-3\15.jpg
# (2048, 2448)
# 0.28919410705566406
# .\Detect\Stop3\15_Detect.jpg
# 0525_images/CCD-3\150.jpg
# (2048, 2448)
# 0.30518412590026855
# .\Detect\Stop3\150_Detect.jpg
# 0525_images/CCD-3\151.jpg
# (2048, 2448)
# 0.30219173431396484
# .\Detect\Stop3\151_Detect.jpg
# 0525_images/CCD-3\152.jpg
# (2048, 2448)
# 0.314129114151001
# .\Detect\Stop3\152_Detect.jpg
# 0525_images/CCD-3\16.jpg
# (2048, 2448)
# 0.30118680000305176
# .\Detect\Stop3\16_Detect.jpg
# 0525_images/CCD-3\17.jpg
# (2048, 2448)
# 0.3031885623931885
# .\Detect\Stop3\17_Detect.jpg
# 0525_images/CCD-3\18.jpg
# (2048, 2448)
# 0.30617642402648926
# .\Detect\Stop3\18_Detect.jpg
# 0525_images/CCD-3\19.jpg
# (2048, 2448)
# 0.28822827339172363
# .\Detect\Stop3\19_Detect.jpg
# 0525_images/CCD-3\2.jpg
# (2048, 2448)
# 0.31917619705200195
# .\Detect\Stop3\2_Detect.jpg
# 0525_images/CCD-3\20.jpg
# (2048, 2448)
# 0.3012228012084961
# .\Detect\Stop3\20_Detect.jpg
# 0525_images/CCD-3\21.jpg
# (2048, 2448)
# 0.317157506942749
# .\Detect\Stop3\21_Detect.jpg
# 0525_images/CCD-3\22.jpg
# (2048, 2448)
# 0.29520559310913086
# .\Detect\Stop3\22_Detect.jpg
# 0525_images/CCD-3\23.jpg
# (2048, 2448)
# 0.2912485599517822
# .\Detect\Stop3\23_Detect.jpg
# 0525_images/CCD-3\24.jpg
# (2048, 2448)
# 0.3011941909790039
# .\Detect\Stop3\24_Detect.jpg
# 0525_images/CCD-3\25.jpg
# (2048, 2448)
# 0.31914615631103516
# .\Detect\Stop3\25_Detect.jpg
# 0525_images/CCD-3\26.jpg
# (2048, 2448)
# 0.3061528205871582
# .\Detect\Stop3\26_Detect.jpg
# 0525_images/CCD-3\27.jpg
# (2048, 2448)
# 0.2902235984802246
# .\Detect\Stop3\27_Detect.jpg
# 0525_images/CCD-3\28.jpg
# (2048, 2448)
# 0.30016565322875977
# .\Detect\Stop3\28_Detect.jpg
# 0525_images/CCD-3\29.jpg
# (2048, 2448)
# 0.3031888008117676
# .\Detect\Stop3\29_Detect.jpg
# 0525_images/CCD-3\3.jpg
# (2048, 2448)
# 0.3081703186035156
# .\Detect\Stop3\3_Detect.jpg
# 0525_images/CCD-3\30.jpg
# (2048, 2448)
# 0.31013917922973633
# .\Detect\Stop3\30_Detect.jpg
# 0525_images/CCD-3\31.jpg
# (2048, 2448)
# 0.352036714553833
# .\Detect\Stop3\31_Detect.jpg
# 0525_images/CCD-3\32.jpg
# (2048, 2448)
# 0.3091874122619629
# .\Detect\Stop3\32_Detect.jpg
# 0525_images/CCD-3\33.jpg
# (2048, 2448)
# 0.30021047592163086
# .\Detect\Stop3\33_Detect.jpg
# 0525_images/CCD-3\34.jpg
# (2048, 2448)
# 0.31316494941711426
# .\Detect\Stop3\34_Detect.jpg
# 0525_images/CCD-3\35.jpg
# (2048, 2448)
# 0.3031599521636963
# .\Detect\Stop3\35_Detect.jpg
# 0525_images/CCD-3\36.jpg
# (2048, 2448)
# 0.281219482421875
# .\Detect\Stop3\36_Detect.jpg
# 0525_images/CCD-3\37.jpg
# (2048, 2448)
# 0.3011913299560547
# .\Detect\Stop3\37_Detect.jpg
# 0525_images/CCD-3\38.jpg
# (2048, 2448)
# 0.30316925048828125
# .\Detect\Stop3\38_Detect.jpg
# 0525_images/CCD-3\39.jpg
# (2048, 2448)
# 0.29021763801574707
# .\Detect\Stop3\39_Detect.jpg
# 0525_images/CCD-3\4.jpg
# (2048, 2448)
# 0.30518627166748047
# .\Detect\Stop3\4_Detect.jpg
# 0525_images/CCD-3\40.jpg
# (2048, 2448)
# 0.3011910915374756
# .\Detect\Stop3\40_Detect.jpg
# 0525_images/CCD-3\41.jpg
# (2048, 2448)
# 0.3022186756134033
# .\Detect\Stop3\41_Detect.jpg
# 0525_images/CCD-3\42.jpg
# (2048, 2448)
# 0.30316638946533203
# .\Detect\Stop3\42_Detect.jpg
# 0525_images/CCD-3\43.jpg
# (2048, 2448)
# 0.3091421127319336
# .\Detect\Stop3\43_Detect.jpg
# 0525_images/CCD-3\44.jpg
# (2048, 2448)
# 0.30817556381225586
# .\Detect\Stop3\44_Detect.jpg
# 0525_images/CCD-3\45.jpg
# (2048, 2448)
# 0.2932438850402832
# .\Detect\Stop3\45_Detect.jpg
# 0525_images/CCD-3\46.jpg
# (2048, 2448)
# 0.30222320556640625
# .\Detect\Stop3\46_Detect.jpg
# 0525_images/CCD-3\47.jpg
# (2048, 2448)
# 0.31815004348754883
# .\Detect\Stop3\47_Detect.jpg
# 0525_images/CCD-3\48.jpg
# (2048, 2448)
# 0.292217493057251
# .\Detect\Stop3\48_Detect.jpg
# 0525_images/CCD-3\49.jpg
# (2048, 2448)
# 0.31417346000671387
# .\Detect\Stop3\49_Detect.jpg
# 0525_images/CCD-3\5.jpg
# (2048, 2448)
# 0.29720044136047363
# .\Detect\Stop3\5_Detect.jpg
# 0525_images/CCD-3\50.jpg
# (2048, 2448)
# 0.29424023628234863
# .\Detect\Stop3\50_Detect.jpg
# 0525_images/CCD-3\51.jpg
# (2048, 2448)
# 0.3151218891143799
# .\Detect\Stop3\51_Detect.jpg
# 0525_images/CCD-3\52.jpg
# (2048, 2448)
# 0.30814528465270996
# .\Detect\Stop3\52_Detect.jpg
# 0525_images/CCD-3\53.jpg
# (2048, 2448)
# 0.31116771697998047
# .\Detect\Stop3\53_Detect.jpg
# 0525_images/CCD-3\54.jpg
# (2048, 2448)
# 0.291217565536499
# .\Detect\Stop3\54_Detect.jpg
# 0525_images/CCD-3\55.jpg
# (2048, 2448)
# 0.31119322776794434
# .\Detect\Stop3\55_Detect.jpg
# 0525_images/CCD-3\56.jpg
# (2048, 2448)
# 0.31019163131713867
# .\Detect\Stop3\56_Detect.jpg
# 0525_images/CCD-3\57.jpg
# (2048, 2448)
# 0.31615161895751953
# .\Detect\Stop3\57_Detect.jpg
# 0525_images/CCD-3\58.jpg
# (2048, 2448)
# 0.30219101905822754
# .\Detect\Stop3\58_Detect.jpg
# 0525_images/CCD-3\59.jpg
# (2048, 2448)
# 0.2972249984741211
# .\Detect\Stop3\59_Detect.jpg
# 0525_images/CCD-3\6.jpg
# (2048, 2448)
# 0.29523754119873047
# .\Detect\Stop3\6_Detect.jpg
# 0525_images/CCD-3\60.jpg
# (2048, 2448)
# 0.3151588439941406
# .\Detect\Stop3\60_Detect.jpg
# 0525_images/CCD-3\61.jpg
# (2048, 2448)
# 0.3091728687286377
# .\Detect\Stop3\61_Detect.jpg
# 0525_images/CCD-3\62.jpg
# (2048, 2448)
# 0.30019664764404297
# .\Detect\Stop3\62_Detect.jpg
# 0525_images/CCD-3\63.jpg
# (2048, 2448)
# 0.3012213706970215
# .\Detect\Stop3\63_Detect.jpg
# 0525_images/CCD-3\64.jpg
# (2048, 2448)
# 0.2852334976196289
# .\Detect\Stop3\64_Detect.jpg
# 0525_images/CCD-3\65.jpg
# (2048, 2448)
# 0.29520750045776367
# .\Detect\Stop3\65_Detect.jpg
# 0525_images/CCD-3\66.jpg
# (2048, 2448)
# 0.2931945323944092
# .\Detect\Stop3\66_Detect.jpg
# 0525_images/CCD-3\67.jpg
# (2048, 2448)
# 0.29019618034362793
# .\Detect\Stop3\67_Detect.jpg
# 0525_images/CCD-3\68.jpg
# (2048, 2448)
# 0.29322171211242676
# .\Detect\Stop3\68_Detect.jpg
# 0525_images/CCD-3\69.jpg
# (2048, 2448)
# 0.2822422981262207
# .\Detect\Stop3\69_Detect.jpg
# 0525_images/CCD-3\7.jpg
# (2048, 2448)
# 0.2981748580932617
# .\Detect\Stop3\7_Detect.jpg
# 0525_images/CCD-3\70.jpg
# (2048, 2448)
# 0.2872316837310791
# .\Detect\Stop3\70_Detect.jpg
# 0525_images/CCD-3\71.jpg
# (2048, 2448)
# 0.2932155132293701
# .\Detect\Stop3\71_Detect.jpg
# 0525_images/CCD-3\72.jpg
# (2048, 2448)
# 0.29520487785339355
# .\Detect\Stop3\72_Detect.jpg
# 0525_images/CCD-3\73.jpg
# (2048, 2448)
# 0.29124903678894043
# .\Detect\Stop3\73_Detect.jpg
# 0525_images/CCD-3\74.jpg
# (2048, 2448)
# 0.2952084541320801
# .\Detect\Stop3\74_Detect.jpg
# 0525_images/CCD-3\75.jpg
# (2048, 2448)
# 0.2832372188568115
# .\Detect\Stop3\75_Detect.jpg
# 0525_images/CCD-3\76.jpg
# (2048, 2448)
# 0.2852356433868408
# .\Detect\Stop3\76_Detect.jpg
# 0525_images/CCD-3\77.jpg
# (2048, 2448)
# 0.3061540126800537
# .\Detect\Stop3\77_Detect.jpg
# 0525_images/CCD-3\78.jpg
# (2048, 2448)
# 0.2931983470916748
# .\Detect\Stop3\78_Detect.jpg
# 0525_images/CCD-3\79.jpg
# (2048, 2448)
# 0.28526806831359863
# .\Detect\Stop3\79_Detect.jpg
# 0525_images/CCD-3\8.jpg
# (2048, 2448)
# 0.2812471389770508
# .\Detect\Stop3\8_Detect.jpg
# 0525_images/CCD-3\80.jpg
# (2048, 2448)
# 0.29322123527526855
# .\Detect\Stop3\80_Detect.jpg
# 0525_images/CCD-3\81.jpg
# (2048, 2448)
# 0.2892429828643799
# .\Detect\Stop3\81_Detect.jpg
# 0525_images/CCD-3\82.jpg
# (2048, 2448)
# 0.28822803497314453
# .\Detect\Stop3\82_Detect.jpg
# 0525_images/CCD-3\83.jpg
# (2048, 2448)
# 0.31013989448547363
# .\Detect\Stop3\83_Detect.jpg
# 0525_images/CCD-3\84.jpg
# (2048, 2448)
# 0.2932429313659668
# .\Detect\Stop3\84_Detect.jpg
# 0525_images/CCD-3\85.jpg
# (2048, 2448)
# 0.29121947288513184
# .\Detect\Stop3\85_Detect.jpg
# 0525_images/CCD-3\86.jpg
# (2048, 2448)
# 0.28623437881469727
# .\Detect\Stop3\86_Detect.jpg
# 0525_images/CCD-3\87.jpg
# (2048, 2448)
# 0.2822756767272949
# .\Detect\Stop3\87_Detect.jpg
# 0525_images/CCD-3\88.jpg
# (2048, 2448)
# 0.28423619270324707
# .\Detect\Stop3\88_Detect.jpg
# 0525_images/CCD-3\89.jpg
# (2048, 2448)
# 0.28823232650756836
# .\Detect\Stop3\89_Detect.jpg
# 0525_images/CCD-3\9.jpg
# (2048, 2448)
# 0.2922184467315674
# .\Detect\Stop3\9_Detect.jpg
# 0525_images/CCD-3\90.jpg
# (2048, 2448)
# 0.28822970390319824
# .\Detect\Stop3\90_Detect.jpg
# 0525_images/CCD-3\91.jpg
# (2048, 2448)
# 0.2902228832244873
# .\Detect\Stop3\91_Detect.jpg
# 0525_images/CCD-3\92.jpg
# (2048, 2448)
# 0.3011956214904785
# .\Detect\Stop3\92_Detect.jpg
# 0525_images/CCD-3\93.jpg
# (2048, 2448)
# 0.3031911849975586
# .\Detect\Stop3\93_Detect.jpg
# 0525_images/CCD-3\94.jpg
# (2048, 2448)
# 0.29723453521728516
# .\Detect\Stop3\94_Detect.jpg
# 0525_images/CCD-3\95.jpg
# (2048, 2448)
# 0.2872319221496582
# .\Detect\Stop3\95_Detect.jpg
# 0525_images/CCD-3\96.jpg
# (2048, 2448)
# 0.28922367095947266
# .\Detect\Stop3\96_Detect.jpg
# 0525_images/CCD-3\97.jpg
# (2048, 2448)
# 0.28127336502075195
# .\Detect\Stop3\97_Detect.jpg
# 0525_images/CCD-3\98.jpg
# (2048, 2448)
# 0.2842392921447754
# .\Detect\Stop3\98_Detect.jpg
# 0525_images/CCD-3\99.jpg
# (2048, 2448)
# 0.293215274810791
# .\Detect\Stop3\99_Detect.jpg
