# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import sklearn
from scipy import ndimage, misc

# %matplotlib inline
import cv2
import glob

img_list = []
filenamelist= []
for img in glob.glob("CCD-1/*.jpg"):
    #img_list.append(cv2.imread(img,0))
    filenamelist.append(img)

# %%
np.array(img_list).shape
# Out:
# (0,)

# %%
np.array(filenamelist).shape
# Out:
# (119,)

# %%
for iter_file in range(len(filenamelist)):
    '''
    if(iter_file<64):
        print(iter_file)
        continue
    '''
    #if filenamelist[iter_file]!= 'CCD-1\\new (22).jpg':
    #    continue
    
    #replace========================
    filename = filenamelist[iter_file]
    print(filename)
    img = np.array(cv2.imread(filename,0))
    #========================

    gray = img

    ret, thresh1 = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)
    #print(gray)

    #print(thresh1)


    contours, hierarchy = cv2.findContours(thresh1,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

    backtorgb = cv2.cvtColor(gray,cv2.COLOR_GRAY2RGB)


    import circle_fit as cf

    circle_point = []

    for i in range(0,np.array(contours).shape[0]):
            if(np.array(contours[i]).shape[0]>1500):
                #print(np.array(contours[i]).shape)

                cor = np.array(contours[i])
                cor = cor.reshape(cor.shape[0],cor.shape[2])
                #print(cor.shape)

                xc,yc,r,_ = cf.least_squares_circle(cor)
                #print(xc,yc,r)
                circle_point.append([xc,yc,r])


    cor = np.array(contours[1])
    cor = cor.reshape(cor.shape[0],cor.shape[2])
    #print(cor.shape)

    xc,yc,r,_ = cf.least_squares_circle(cor)
    #print(xc,yc,r)




    print("Image_{}".format(iter_file))
    ResultImage = np.zeros((img.shape[0],img.shape[1],3))
    #print(img_list[8].shape)
    #print( img_list[8][:int(xc),int(yc):].shape)
    Temp = []

    FullImage = img
    closing_backtorgb =  cv2.cvtColor(FullImage,cv2.COLOR_GRAY2RGB)

    for fourlook in range(4):
        if(fourlook==0):
            start_x = int(xc)
            start_y = int(yc)
            img_temp =img[int(xc):,int(yc):]

        elif(fourlook==1):
            start_x = 0 
            start_y = int(yc)
            img_temp = img[:int(xc),int(yc):]
        elif(fourlook==2):
            start_x = int(xc)
            start_y = 0
            img_temp =img[int(xc):,:int(yc)]
        else:
            start_x = 0
            start_y = 0
            img_temp = img[:int(xc),:int(yc)]

        #print(i,"===",img_temp.shape, " Startx: ",start_x, " Starty: ",start_y)




        #==========================================

        img_temp = ndimage.minimum_filter(img_temp, size=5)


        kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])


        sharpen_img = cv2.addWeighted(img_temp, 10, cv2.blur(img_temp, (50,50)), -10, 128)
        ret,thresh1 = cv2.threshold(sharpen_img,0,1,cv2.THRESH_BINARY_INV)#THRESH_TOZERO_INV

        kernel = np.ones((3,3),np.uint8)
        mask = cv2.morphologyEx(thresh1, cv2.MORPH_OPEN, kernel)

        #mask====================================

        img_temp_mask = img_temp* mask


        #img_temp = sharpen_img

        block_size = (3,3)
        block_img = []
        block_std = []

        original_shape = img_temp.shape
        #print(original_shape)
        for w in range(block_size[0],img_temp.shape[0],block_size[0]):
            temp = []
            #temp_std = []
            for h in range(block_size[1],img_temp.shape[1],block_size[1]):
                #print(np.array(img_temp[w-block_size[0]:w,h-block_size[1]:h]).shape)
                temp.append(np.mean(img_temp[w-block_size[0]:w,h-block_size[1]:h]))
                #temp_std.append(np.std(img_temp[w-block_size[0]:w,h-block_size[1]:h]))

            #block_std.append(temp_std)
            block_img.append(temp)

        block_img = np.array(block_img,np.uint8)


        block_img = cv2.resize(block_img,(original_shape[1],original_shape[0]))
        block_img.shape
        
        #plt.figure(figsize=(20,20))
        #plt.imshow(block_img,cmap = 'gray')
        

        #block_img = np.array(block_img)

        sharpen_img = cv2.addWeighted(block_img, 10, cv2.blur(block_img, (30,30)), -10, 128)
        ret,thresh1 = cv2.threshold(sharpen_img,0,1,cv2.THRESH_BINARY_INV)#THRESH_TOZERO_INV

        kernel = np.ones((3,3),np.uint8)
        mask = cv2.morphologyEx(thresh1, cv2.MORPH_OPEN, kernel)


        #block_img = np.array(img_temp)
        #block_img = np.array(block_img)
        #print(block_img)


        #threshold
        ret,thresh1 = cv2.threshold(block_img,90,255,cv2.THRESH_BINARY_INV)#THRESH_TOZERO_INV
        #thresh1 = cv2.adaptiveThreshold(block_img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,3,2)
        '''
        plt.figure(figsize=(20,20))
        plt.imshow(thresh1,cmap = 'gray')
        '''
        kernel = np.ones((11,11),np.uint8)

        #opening = cv2.morphologyEx(thresh1, cv2.MORPH_OPEN, kernel)
        closing = cv2.morphologyEx(thresh1, cv2.MORPH_CLOSE, kernel)

        '''
        plt.figure(figsize=(20,20))
        plt.imshow(closing,cmap = 'gray')
        '''

        closing = closing * mask


        closing = cv2.morphologyEx(closing, cv2.MORPH_CLOSE, kernel)

        # 消除外圍edge
        #closing = black_img * closing
        #plt.figure(figsize=(20,20))
        #plt.imshow(closing,cmap = 'gray')
        label = []
        nlabels, labels, stats, centroids = cv2.connectedComponentsWithStats(closing)

        #==========================================================
        backtorgb = cv2.cvtColor(closing,cv2.COLOR_GRAY2RGB)

        for i in range(0,np.array(contours).shape[0]):
            #if(np.array(contours[i]).shape[0]>1500):
                cv2.drawContours(backtorgb,contours[i],-1,(0,0,255),3)

        '''        
        plt.figure(figsize=(20,20))
        plt.imshow(backtorgb)     
        '''
        #==========================================================


        #===========分開邊界和真正的瑕疵=============================


        #print(closing.shape)

        white_x , white_y = np.where(closing != 0)

        white_radius = ((white_x-closing.shape[0])**2+(white_y-closing.shape[1])**2)**0.5

        #print(np.min(white_radius))
        #print(np.max(white_radius))

        #==========================================================
        #圓圖在img_temp


        #closing_backtorgb =  cv2.cvtColor(img_temp,cv2.COLOR_GRAY2RGB)

        for i in range(0,len(stats)):
            area = stats[i][4]
            if(area < 10000 and area > 350):
                Bounding_Box_Area = stats[i][2]*stats[i][3]
                X_Width,Y_Width = stats[i][2],stats[i][3]
                #print("Area: ",area,"; X_Width: ",X_Width,"; Y_Width: ",Y_Width,"; Bounding_Box_Area: ",Bounding_Box_Area)

                #cv2.rectangle(closing_backtorgb, (stats[i][0], stats[i][1]), (stats[i][0]+stats[i][2], stats[i][1]+stats[i][3]), (0, 255,255 ), 1)
                #if(Bounding_Box_Area/area<10): # stage2: 消除邊界
                #    cv2.rectangle(closing_backtorgb, (stats[i][0],stats[i][1]), (stats[i][0]+stats[i][2], stats[i][1]+stats[i][3]), ( 255,0,0 ), 1)

                #cv2.rectangle(closing_backtorgb, (start_y+stats[i][0], start_x+stats[i][1]), (start_y+stats[i][0]+stats[i][2], start_x+stats[i][1]+stats[i][3]), (0, 255,255 ), 1)
                if(Bounding_Box_Area/area<15): # stage2: 消除邊界
                    plt.figure(figsize=(20,20))
                    
                    Array = FullImage[start_x+stats[i][1]-50:start_x+stats[i][1]+stats[i][3]+50,start_y+stats[i][0]-50:start_y+stats[i][0]+stats[i][2]+50]
                    
                    Mean = Array[Array<200].mean()
                    std = Array[Array<200].std()
                    #print(Array[Array<Mean-2.3*std].shape[0]/Array.shape[0])
                    cv2.imwrite(".\\SmallWindow\\{}".format(Array[Array<200].mean())+'_Detect.jpg',Array)
                    cv2.rectangle(closing_backtorgb, (start_y+stats[i][0], start_x+stats[i][1]), (start_y+stats[i][0]+stats[i][2], start_x+stats[i][1]+stats[i][3]), ( 255,0,0 ), 1)
                    plt.close()
                    

        #plt.figure(figsize=(20,20))
        #plt.imshow(closing_backtorgb) 
        #plt.figure(figsize=(20,20))
        #plt.imshow(closing_backtorgb)

        #print(closing_backtorgb.shape)
        #print(ResultImage.shape)
        #esultImage.paste(closing_backtorgb, (0,0))
    '''      
        if(fourlook==0):
            print(";;;",ResultImage[int(xc):,int(yc):].shape)
            #temp = closing_backtorgb.copy()
            #Temp.append(closing_backtorgb.copy())
            np.copyto(ResultImage[int(xc):,int(yc):],closing_backtorgb)
        elif(fourlook==1):
            Temp.append(closing_backtorgb.copy())
            ResultImage[:int(xc),int(yc):] = copy.deepcopy( closing_backtorgb)
        elif(fourlook==2):
            ResultImage[int(xc):,:int(yc)] = closing_backtorgb.astype(int)
        else:
            ResultImage[:int(xc),:int(yc)] = closing_backtorgb.astype(int)
    '''

    #print(closing_backtorgb.astype(int))
    plt.figure(figsize=(20,20))
    plt.imshow(closing_backtorgb)
    print(".\\Detect\\" +filenamelist[iter_file][5:-4]+'_Detect.jpg')
    cv2.imwrite(".\\Detect\\" +filenamelist[iter_file][5:-4]+'_Detect.jpg',closing_backtorgb)
    plt.close()
# Out:
# CCD-1\new (1).jpg
# Image_0
# .\Detect\\new (1)_Detect.jpg
# CCD-1\new (10).jpg
# Image_1
# .\Detect\\new (10)_Detect.jpg
# CCD-1\new (100).jpg
# Image_2
# .\Detect\\new (100)_Detect.jpg
# CCD-1\new (103).jpg
# Image_3
# .\Detect\\new (103)_Detect.jpg
# CCD-1\new (106).jpg
# Image_4
# .\Detect\\new (106)_Detect.jpg
# CCD-1\new (109).jpg
# Image_5
# .\Detect\\new (109)_Detect.jpg
# CCD-1\new (11).jpg
# Image_6
# .\Detect\\new (11)_Detect.jpg
# CCD-1\new (111).jpg
# Image_7
# .\Detect\\new (111)_Detect.jpg
# CCD-1\new (112).jpg
# Image_8
# .\Detect\\new (112)_Detect.jpg
# CCD-1\new (113).jpg
# Image_9
# .\Detect\\new (113)_Detect.jpg
# CCD-1\new (116).jpg
# Image_10
# .\Detect\\new (116)_Detect.jpg
